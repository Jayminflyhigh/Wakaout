# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
imdata = cv2.imread('./data/Candy/IMG_8564.JPG')

# %%
plt.imshow(imdata)
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# cv2.
